# %% [markdown]
# <a href="https://colab.research.google.com/github/lucianoon/1/blob/main/ChatGPT_para_Ci%C3%AAncia_de_Dados_e_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ChatGPT para Ciência de Dados e Machine Learning

# %% [markdown]
# # Exploração inicial dos dados

# %%
import pandas as pd

# Carrega o arquivo CSV em um DataFrame
data = pd.read_csv('census.csv')

# Mostra as primeiras 5 linhas do DataFrame para verificar os dados
print(data.head())

# Mostra informações gerais sobre o DataFrame
print(data.info())

# Calcula estatísticas descritivas para colunas numéricas
print(data.describe())

# Calcula a contagem de valores únicos para a coluna 'income' com espaço em branco removido
income_counts = data['income'].str.strip().value_counts()
print(income_counts)

# Calcula a média da idade
print(f"Média de idade: {data['age'].mean()} anos")

# Calcula a porcentagem de pessoas com renda maior que 50K
percentage_greater_than_50k = (income_counts['>50K'] / len(data)) * 100
print(f"Porcentagem de pessoas com renda >50K: {percentage_greater_than_50k:.2f}%")
# Out:
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# ...

# %%
import pandas as pd

# Carrega o arquivo CSV em um DataFrame
data = pd.read_csv('census.csv')

# Amostra das primeiras linhas do DataFrame
print("Amostra das primeiras linhas:")
print(data.head())

# Estatísticas das colunas numéricas
print("\nEstatísticas das colunas numéricas:")
print(data.describe())

# Contagem de valores únicos para colunas categóricas
categorical_columns = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']
for column in categorical_columns:
    unique_values = data[column].unique()
    unique_count = len(unique_values)
    print(f"\nContagem de valores únicos para '{column}': {unique_count} valores únicos")
    print(unique_values)

# Contagem de valores únicos para a coluna de classe (income)
income_counts = data['income'].str.strip().value_counts()
print("\nContagem de valores únicos para a coluna de classe (income):")
print(income_counts)
# Out:
# Amostra das primeiras linhas:
#    age          workclass  final-weight   education  education-num  \
# 0   39          State-gov         77516   Bachelors             13
# 1   50   Self-emp-not-inc         83311   Bachelors             13
# 2   38            Private        215646     HS-grad              9
# 3   53            Private        234721        11th              7
# 4   28            Private        338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loos  hour-per-week  native-country  income
# ...

# %%
import pandas as pd

# Carrega o arquivo CSV em um DataFrame
data = pd.read_csv('census.csv')

# Mostra os tipos de dados das colunas
print("Tipos de dados das colunas:")
print(data.dtypes)
# Out:
# Tipos de dados das colunas:
# age                int64
# workclass         object
# final-weight       int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loos       int64
# hour-per-week      int64
# native-country    object
# income            object
# dtype: object

# %%
import pandas as pd

# Carrega o arquivo CSV em um DataFrame
data = pd.read_csv('census.csv')

# Verifica se existem dados faltantes em cada coluna
missing_data = data.isnull().sum()

# Verifica se existem dados faltantes em todo o DataFrame
total_missing = missing_data.sum()

if total_missing == 0:
    print("Não existem dados faltantes no conjunto de dados.")
else:
    print("Existem dados faltantes no conjunto de dados. Aqui está a contagem por coluna:")
    print(missing_data)
    print(f"Total de dados faltantes: {total_missing}")
# Out:
# Não existem dados faltantes no conjunto de dados.

# %%
import pandas as pd

# Carrega o arquivo CSV em um DataFrame
data = pd.read_csv('census.csv')

# Lista de colunas categóricas
categorical_columns = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']

# Verifica se existem valores "?" em cada coluna categórica
for column in categorical_columns:
    has_question_mark = data[column].str.contains('\?').any()
    if has_question_mark:
        print(f"Na coluna '{column}' existem valores '?'")
    else:
        print(f"Na coluna '{column}' não existem valores '?'")
# Out:
# Na coluna 'workclass' existem valores '?'
# Na coluna 'education' não existem valores '?'
# Na coluna 'marital-status' não existem valores '?'
# Na coluna 'occupation' existem valores '?'
# Na coluna 'relationship' não existem valores '?'
# Na coluna 'race' não existem valores '?'
# Na coluna 'sex' não existem valores '?'
# Na coluna 'native-country' existem valores '?'

# %%
# Lista de colunas categóricas
categorical_columns = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']

# Inicializa um dicionário para armazenar a contagem de substituições por coluna
substitution_counts = {}

# Substitui o caractere "?" por nulo (NaN) nas colunas categóricas e conta as substituições
for column in categorical_columns:
    substitution_count = data[column].str.count('\?').sum()
    data[column] = data[column].replace(' ?', None)
    substitution_counts[column] = substitution_count

# Exibe a quantidade de substituições por coluna
print("Quantidade de substituições por coluna:")
for column, count in substitution_counts.items():
    print(f"'{column}': {count} substituições")
# Out:
# Quantidade de substituições por coluna:
# 'workclass': 1836 substituições
# 'education': 0 substituições
# 'marital-status': 0 substituições
# 'occupation': 1843 substituições
# 'relationship': 0 substituições
# 'race': 0 substituições
# 'sex': 0 substituições
# 'native-country': 583 substituições

# %%
# Verifica se existem dados faltantes em cada coluna
missing_data = data.isnull().sum()

# Verifica se existem dados faltantes em todo o DataFrame
total_missing = missing_data.sum()

if total_missing == 0:
    print("Não existem dados faltantes no conjunto de dados.")
else:
    print("Existem dados faltantes no conjunto de dados. Aqui está a contagem por coluna:")
    print(missing_data)
    print(f"Total de dados faltantes: {total_missing}")
# Out:
# Existem dados faltantes no conjunto de dados. Aqui está a contagem por coluna:
# age                  0
# workclass         1836
# final-weight         0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loos         0
# hour-per-week        0
# native-country     583
# income               0
# dtype: int64
# Total de dados faltantes: 4262

# %%
# Verifica quais colunas possuem valores faltantes
columns_with_missing_values = data.columns[data.isnull().any()]

# Mostra o tipo das colunas com valores faltantes
print("Tipos das colunas com valores faltantes:")
for column in columns_with_missing_values:
    column_type = data[column].dtype
    print(f"'{column}': {column_type}")
# Out:
# Tipos das colunas com valores faltantes:
# 'workclass': object
# 'occupation': object
# 'native-country': object

# %%
# Liste as colunas categóricas
categorical_columns = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']

# Preencha os valores faltantes nas colunas categóricas com a moda (valor mais frequente)
for column in categorical_columns:
    # Substitua os valores faltantes (NaN) pelo valor mais frequente (moda)
    mode_value = data[column].mode()[0]  # Obtenha o valor mais frequente (moda)
    data[column].fillna(mode_value, inplace=True)

# %%
# Verifica se existem dados faltantes em cada coluna
missing_data = data.isnull().sum()

# Verifica se existem dados faltantes em todo o DataFrame
total_missing = missing_data.sum()

if total_missing == 0:
    print("Não existem dados faltantes no conjunto de dados.")
else:
    print("Existem dados faltantes no conjunto de dados. Aqui está a contagem por coluna:")
    print(missing_data)
    print(f"Total de dados faltantes: {total_missing}")
# Out:
# Não existem dados faltantes no conjunto de dados.

# %%
# Liste as colunas numéricas para análise de outliers
numeric_columns = ['age', 'final-weight', 'education-num', 'capital-gain', 'capital-loos', 'hour-per-week']

# Defina um limite para identificar outliers (por exemplo, 3 desvios padrão)
outlier_threshold = 3

# Função para identificar outliers em uma coluna
def identify_outliers(column):
    mean = column.mean()
    std = column.std()
    lower_limit = mean - outlier_threshold * std
    upper_limit = mean + outlier_threshold * std
    outliers = (column < lower_limit) | (column > upper_limit)
    return outliers

# Identifique e analise outliers em cada coluna numérica
for column_name in numeric_columns:
    column = data[column_name]
    outliers = identify_outliers(column)

    # Exiba o resultado da análise da coluna
    print(f"Análise da coluna '{column_name}':")
    print(f" - Número total de outliers: {outliers.sum()}")
    print(f" - Valor médio: {column.mean()}")
    print(f" - Desvio padrão: {column.std()}")
    print(f" - Limite inferior para outliers: {column.mean() - outlier_threshold * column.std()}")
    print(f" - Limite superior para outliers: {column.mean() + outlier_threshold * column.std()}")
    print("\n")

# Exiba um resumo das colunas com outliers
print("Colunas com outliers:")
for column_name in numeric_columns:
    column = data[column_name]
    if identify_outliers(column).any():
        print(f"'{column_name}' tem outliers.")
# Out:
# Análise da coluna 'age':
#  - Número total de outliers: 121
#  - Valor médio: 38.58164675532078
#  - Desvio padrão: 13.640432553581341
#  - Limite inferior para outliers: -2.339650905423241
#  - Limite superior para outliers: 79.5029444160648
#
#
# Análise da coluna 'final-weight':
#  - Número total de outliers: 347
#  - Valor médio: 189778.36651208502
#  - Desvio padrão: 105549.97769702224
#  - Limite inferior para outliers: -126871.5665789817
#  - Limite superior para outliers: 506428.29960315174
#
#
# Análise da coluna 'education-num':
#  - Número total de outliers: 219
#  - Valor médio: 10.0806793403151
#  - Desvio padrão: 2.5727203320673877
#  - Limite inferior para outliers: 2.362518344112937
#  - Limite superior para outliers: 17.798840336517266
#
#
# Análise da coluna 'capital-gain':
#  - Número total de outliers: 215
#  - Valor médio: 1077.6488437087312
#  - Desvio padrão: 7385.292084840338
#  - Limite inferior para outliers: -21078.227410812284
# ...

# %% [markdown]
# # Geração de gráficos

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Limpeza de dados: Remova linhas com valores não numéricos nas colunas relevantes
numeric_columns = ['age', 'hour-per-week', 'capital-gain', 'capital-loos']
data[numeric_columns] = data[numeric_columns].apply(pd.to_numeric, errors='coerce')
data = data.dropna(subset=numeric_columns)

# 1. Gráfico de Dispersão: Idade x Horas por Semana
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='hour-per-week', data=data, alpha=0.3)
plt.title('Gráfico de Dispersão: Idade x Horas por Semana')
plt.xlabel('Idade')
plt.ylabel('Horas por Semana')
plt.grid(True)
plt.show()

# 2. Gráfico de Barras: Educação Numérica x Renda Média
plt.figure(figsize=(12, 6))
sns.barplot(x='education-num', y='income', data=data, estimator=lambda x: x.mean(), palette='viridis')
plt.title('Gráfico de Barras: Educação Numérica x Renda Média')
plt.xlabel('Nível de Educação Numérico')
plt.ylabel('Renda Média')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# 3. Matriz de Correlação: Ganhos de Capital x Perda de Capital
capital_data = data[['capital-gain', 'capital-loos']]
correlation_matrix = capital_data.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Matriz de Correlação: Ganhos de Capital x Perda de Capital')
plt.tight_layout()
plt.show()

# %%
# !pip install squarify

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Defina o tamanho padrão das figuras
plt.rcParams['figure.figsize'] = (12, 6)

# 1. Gráfico de Barras (Bar Chart)
plt.subplot(3, 3, 1)
sns.countplot(x='income', data=data)
plt.title('Gráfico de Barras: Renda')

# 2. Gráfico de Barras Empilhadas (Stacked Bar Chart)
plt.subplot(3, 3, 2)
sns.countplot(x='income', hue='sex', data=data)
plt.title('Gráfico de Barras Empilhadas: Renda por Sexo')

# 3. Gráfico de Pizza (Pie Chart)
plt.subplot(3, 3, 3)
income_counts = data['income'].value_counts()
plt.pie(income_counts, labels=income_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Gráfico de Pizza: Distribuição de Renda')

# 4. Gráfico de Rosca (Donut Chart)
plt.subplot(3, 3, 4)
income_counts = data['income'].value_counts()
plt.pie(income_counts, labels=income_counts.index, autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.4))
plt.title('Gráfico de Rosca: Distribuição de Renda')

# 5. Gráfico de Barras Horizontais (Horizontal Bar Chart)
plt.subplot(3, 3, 5)
sns.countplot(y='income', data=data)
plt.title('Gráfico de Barras Horizontais: Renda')

# 6. Gráfico de Setores (Treemap)
import squarify
plt.subplot(3, 3, 6)
income_counts = data['income'].value_counts()
squarify.plot(sizes=income_counts, label=income_counts.index, alpha=0.7)
plt.axis('off')
plt.title('Gráfico de Setores: Distribuição de Renda')

# 7. Gráfico de Pareto
plt.subplot(3, 3, 7)
income_counts = data['income'].value_counts()
income_cumulative = income_counts.cumsum() / income_counts.sum()
sns.barplot(x=income_counts.index, y=income_cumulative, color='skyblue')
plt.title('Gráfico de Pareto: Distribuição de Renda')

# 8. Gráfico de Frequência (Frequency Plot)
plt.subplot(3, 3, 8)
sns.histplot(data=data, x='income', bins=2, discrete=True)
plt.title('Gráfico de Frequência: Renda')

# 9. Gráfico de Caixas (Box Plot)
plt.subplot(3, 3, 9)
sns.boxplot(x='income', y='age', data=data)
plt.title('Gráfico de Caixas: Idade por Renda')

# Ajuste o layout das figuras
plt.tight_layout()

# Exiba os gráficos
plt.show()

# %%
import matplotlib.pyplot as plt

# Filtrar apenas as colunas categóricas
categorical_columns = data.select_dtypes(include=['object'])

# Contagem de valores únicos em cada coluna categórica
unique_value_counts = categorical_columns.nunique()

# Crie um gráfico de barras
plt.figure(figsize=(12, 6))
unique_value_counts.plot(kind='bar', color='skyblue')
plt.title('Quantidade de Valores Únicos por Coluna Categórica')
plt.xlabel('Coluna Categórica')
plt.ylabel('Quantidade de Valores Únicos')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Exiba o gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Filtrar apenas as colunas categóricas
categorical_columns = data.select_dtypes(include=['object'])

# Loop através das colunas categóricas e criar um gráfico de barras para cada uma
for column in categorical_columns.columns:
    unique_values = categorical_columns[column].nunique()
    value_counts = categorical_columns[column].value_counts()

    plt.figure(figsize=(12, 6))
    value_counts.plot(kind='bar', color='skyblue')
    plt.title(f'Valores Únicos em {column}')
    plt.xlabel(f'Valores Únicos ({unique_values} no total)')
    plt.ylabel('Contagem')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()

    # Exiba o gráfico
    plt.show()

# %%
import matplotlib.pyplot as plt

# Filtrar apenas as colunas categóricas
categorical_columns = data.select_dtypes(include=['object'])

# Loop através das colunas categóricas e criar um gráfico de barras para cada uma
for column in categorical_columns.columns:
    unique_values = categorical_columns[column].nunique()
    value_counts = categorical_columns[column].value_counts()

    plt.figure(figsize=(12, 6))
    ax = value_counts.plot(kind='bar', color='skyblue')
    plt.title(f'Valores Únicos em {column}')
    plt.xlabel(f'Valores Únicos ({unique_values} no total)')
    plt.ylabel('Contagem')
    plt.xticks(rotation=45, ha='right')

    # Adicione o número de valores únicos no topo de cada barra
    for i, v in enumerate(value_counts):
        ax.text(i, v + 10, str(v), ha='center', va='bottom', fontsize=8)

    plt.tight_layout()

    # Exiba o gráfico
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Carregue o arquivo CSV em um DataFrame
data = pd.read_csv('census.csv')

# Defina o tamanho padrão das figuras
plt.rcParams['figure.figsize'] = (12, 6)

# 1. Histograma
plt.subplot(3, 3, 1)
sns.histplot(data=data, x='age', bins=20, kde=True, color='skyblue')
plt.title('Histograma de Idade')
plt.xlabel('Idade')
plt.ylabel('Contagem')

# 2. Gráfico de Barras (Média)
plt.subplot(3, 3, 2)
age_grouped = data.groupby('income')['age'].mean()
age_grouped.plot(kind='bar', color='skyblue')
plt.title('Média de Idade por Renda')
plt.xlabel('Renda')
plt.ylabel('Média de Idade')

# 3. Gráfico de Caixas (Box Plot)
plt.subplot(3, 3, 3)
sns.boxplot(x='age', data=data, color='skyblue')
plt.title('Gráfico de Caixas: Idade')
plt.xlabel('Idade')

# 4. Gráfico de Dispersão (com ele mesmo para fins ilustrativos)
plt.subplot(3, 3, 4)
sns.scatterplot(x='age', y='age', data=data, alpha=0.3, color='skyblue')
plt.title('Gráfico de Dispersão: Idade x Idade')
plt.xlabel('Idade')
plt.ylabel('Idade')

# 5. Gráfico de Linha (Média por Idade)
plt.subplot(3, 3, 5)
age_grouped = data.groupby('age')['age'].count()
age_grouped.plot(kind='line', color='skyblue')
plt.title('Gráfico de Linha: Contagem por Idade')
plt.xlabel('Idade')
plt.ylabel('Contagem')

# 6. Gráfico de Área (Média por Idade)
plt.subplot(3, 3, 6)
age_grouped = data.groupby('age')['age'].count()
age_grouped.plot(kind='area', color='skyblue', alpha=0.5)
plt.title('Gráfico de Área: Contagem por Idade')
plt.xlabel('Idade')
plt.ylabel('Contagem')

# 7. Gráfico de Violino
plt.subplot(3, 3, 7)
sns.violinplot(x='income', y='age', data=data, palette='viridis')
plt.title('Gráfico de Violino: Idade por Renda')
plt.xlabel('Renda')
plt.ylabel('Idade')

# 8. Gráfico de Correlação (com ele mesmo para fins ilustrativos)
plt.subplot(3, 3, 8)
correlation_matrix = data[['age', 'age']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Gráfico de Correlação: Idade x Idade')

# 9. Gráfico de Bolhas (com ele mesmo para fins ilustrativos)
plt.subplot(3, 3, 9)
sns.scatterplot(x='age', y='age', data=data, size='age', sizes=(10, 200), alpha=0.5, color='skyblue')
plt.title('Gráfico de Bolhas: Idade x Idade')
plt.xlabel('Idade')
plt.ylabel('Idade')

# Ajuste o layout das figuras
plt.tight_layout()

# Exiba os gráficos
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Selecione apenas os atributos numéricos
numeric_data = data.select_dtypes(include=['int64', 'float64'])

# Calcule a matriz de correlação
correlation_matrix = numeric_data.corr()

# Crie um mapa de calor para visualizar a matriz de correlação
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Matriz de Correlação entre Atributos Numéricos')
plt.tight_layout()

# Exiba o mapa de calor
plt.show()

# %%
import pandas as pd
import plotly.figure_factory as ff


# Selecionar apenas os atributos numéricos
numeric_data = data.select_dtypes(include=['int64', 'float64'])

# Calcular a matriz de correlação com uma casa decimal
correlation_matrix = numeric_data.corr().round(3)

# Configurar a figura interativa
fig = ff.create_annotated_heatmap(z=correlation_matrix.values,
                                  x=list(correlation_matrix.columns),
                                  y=list(correlation_matrix.index),
                                  colorscale='Viridis')

# Configurar o layout da figura
fig.update_layout(
    title="Matriz de Correlação Dinâmica",
    xaxis_title="Atributos",
    yaxis_title="Atributos",
    width=800,
    height=800,
    xaxis=dict(tickfont=dict(size=8)),
    yaxis=dict(tickfont=dict(size=8)),
    coloraxis_colorbar=dict(title='Correlação', titleside='right', ticks='outside'),
)

# Mostrar a figura interativa
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import plotly.express as px


# Criar um gráfico de dispersão dinâmico com Plotly Express
fig = px.scatter(data, x='age', y='hour-per-week', color='income', hover_name='age', title='Gráfico de Dispersão Idade vs. Renda')

# Configurar o layout do gráfico
fig.update_layout(
    xaxis_title='Idade',
    yaxis_title='Renda',
    showlegend=False,  # Para ocultar a legenda de cores
)

# Mostrar o gráfico interativo
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd


# Filtrar apenas pessoas do gênero masculino
male_data = data[data['sex'] == ' Male']

# Crie o gráfico de dispersão dinâmico
fig = px.scatter(
    male_data,
    x='age',
    y='capital-gain',
    color='income',
    title='Gráfico de Dispersão Dinâmico: Idade vs. Ganho de Capital (Gênero Masculino)',
    labels={'age': 'Idade', 'capital-gain': 'Ganho de Capital'}
)

# Adicione uma opção de zoom e pan
fig.update_xaxes(type='linear')
fig.update_yaxes(type='linear')

# Exiba o gráfico de dispersão dinâmico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Atributos categóricos - Label Encoder

# %%
data
# Out:
#        age          workclass  final-weight    education  education-num  \
# 0       39          State-gov         77516    Bachelors             13
# 1       50   Self-emp-not-inc         83311    Bachelors             13
# 2       38            Private        215646      HS-grad              9
# 3       53            Private        234721         11th              7
# 4       28            Private        338409    Bachelors             13
# ...    ...                ...           ...          ...            ...
# 32556   27            Private        257302   Assoc-acdm             12
# 32557   40            Private        154374      HS-grad              9
# 32558   58            Private        151910      HS-grad              9
# 32559   22            Private        201490      HS-grad              9
# 32560   52       Self-emp-inc        287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Selecione as colunas categóricas que deseja codificar
categorical_columns = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country', 'income']

# Inicialize o LabelEncoder
label_encoder = LabelEncoder()

# Codifique cada coluna categórica
for column in categorical_columns:
    data[column] = label_encoder.fit_transform(data[column])

data
# Out:
#        age  workclass  final-weight  education  education-num  marital-status  \
# 0       39          6         77516          9             13               4
# 1       50          5         83311          9             13               2
# 2       38          3        215646         11              9               0
# 3       53          3        234721          1              7               2
# 4       28          3        338409          9             13               2
# ...    ...        ...           ...        ...            ...             ...
# 32556   27          3        257302          7             12               2
# 32557   40          3        154374         11              9               2
# 32558   58          3        151910         11              9               6
# 32559   22          3        201490         11              9               4
# 32560   52          4        287927         11              9               2
#
# ...

# %%
# Conte a ocorrência de cada valor único na coluna "income"
value_counts = data['income'].value_counts()

# Exiba a quantidade para cada valor possível
print("Quantidade para cada valor possível no atributo 'income':")
print(value_counts)
# Out:
# Quantidade para cada valor possível no atributo 'income':
# 0    24720
# 1     7841
# Name: income, dtype: int64

# %% [markdown]
# ## Tratamento do desbalanceamento

# %%
from imblearn.over_sampling import SMOTE

# Separar as features (X) e o target (y)
X = data.drop('income', axis=1)
y = data['income']

# Inicialize o SMOTE
smote = SMOTE(random_state=42)

# Aplicar o SMOTE para criar dados sintéticos
X_resampled, y_resampled = smote.fit_resample(X, y)

# Agora X_resampled e y_resampled contêm os dados balanceados
# Você pode treinar seu modelo de machine learning com esses dados

# Verificar a distribuição de classes após o SMOTE
print("Distribuição de classes após o SMOTE:")
print(y_resampled.value_counts())
# Out:
# Distribuição de classes após o SMOTE:
# 0    24720
# 1    24720
# Name: income, dtype: int64

# %%
X_resampled
# Out:
#        age  workclass  final-weight  education  education-num  marital-status  \
# 0       39          6         77516          9             13               4
# 1       50          5         83311          9             13               2
# 2       38          3        215646         11              9               0
# 3       53          3        234721          1              7               2
# 4       28          3        338409          9             13               2
# ...    ...        ...           ...        ...            ...             ...
# 49435   42          3        139001         14             10               2
# 49436   45          3        333899          9             13               2
# 49437   40          4         57233          9             10               2
# 49438   58          3        150390          9             13               4
# 49439   41          2        183765         12             10               1
#
# ...

# %% [markdown]
# ## Atributos categóricos - OneHotEncoding

# %%
# Pálio - 0
# Gol   - 1
# Uno   - 2

# Pálio 1 0 0
# Gol   0 1 0
# Uno   0 0 1

# %%
# Selecione apenas as colunas categóricas para aplicar o One-Hot Encoding
categorical_columns = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']

# Aplique o One-Hot Encoding usando get_dummies
data_encoded = pd.get_dummies(X_resampled, columns=categorical_columns)

# %%
data_encoded
# Out:
#        age  final-weight  education-num  capital-gain  capital-loos  \
# 0       39         77516             13          2174             0
# 1       50         83311             13             0             0
# 2       38        215646              9             0             0
# 3       53        234721              7             0             0
# 4       28        338409             13             0             0
# ...    ...           ...            ...           ...           ...
# 49435   42        139001             10             0             0
# 49436   45        333899             13             0             0
# 49437   40         57233             10             0             0
# 49438   58        150390             13             0             0
# 49439   41        183765             10             0             0
#
#        hour-per-week  workclass_0  workclass_1  workclass_2  workclass_3  ...  \
# ...

# %% [markdown]
# ## Padronização

# %%
from sklearn.preprocessing import StandardScaler

# Crie um objeto StandardScaler
scaler = StandardScaler()

# Selecione apenas as colunas numéricas para a padronização (excluindo a coluna alvo, se houver)
numeric_columns = data_encoded.select_dtypes(include=['number']).columns

# Aplique a padronização às colunas numéricas
data_encoded[numeric_columns] = scaler.fit_transform(data_encoded[numeric_columns])

# %%
data_encoded
# Out:
#             age  final-weight  education-num  capital-gain  capital-loos  \
# 0     -0.106436     -1.067722       1.034900      0.013732     -0.257101
# 1      0.779494     -1.012399       1.034900     -0.196484     -0.257101
# 2     -0.186975      0.250965      -0.603902     -0.196484     -0.257101
# 3      1.021111      0.433069      -1.423304     -0.196484     -0.257101
# 4     -0.992365      1.422948       1.034900     -0.196484     -0.257101
# ...         ...           ...            ...           ...           ...
# 49435  0.135181     -0.480742      -0.194202     -0.196484     -0.257101
# 49436  0.376799      1.379893       1.034900     -0.196484     -0.257101
# 49437 -0.025897     -1.261358      -0.194202     -0.196484     -0.257101
# 49438  1.423806     -0.372015       1.034900     -0.196484     -0.257101
# 49439  0.054642     -0.053393      -0.194202     -0.196484     -0.257101
#
#        hour-per-week  workclass_0  workclass_1  workclass_2  workclass_3  ...  \
# ...

# %% [markdown]
# ## Divisão da base de dados

# %%
from sklearn.model_selection import train_test_split

# Divida os dados em treinamento (70%) e teste (30%)
X_train, X_test, y_train, y_test = train_test_split(data_encoded, y_resampled, test_size=0.3, random_state=42)

# Agora, X_train e y_train contêm os dados de treinamento, e X_test e y_test contêm os dados de teste.

# %%
X_train.shape, y_train.shape
# Out:
# ((34608, 105), (34608,))

# %%
X_test.shape, y_test.shape
# Out:
# ((14832, 105), (14832,))

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Algoritmos e avaliação

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis, LinearDiscriminantAnalysis
from sklearn.cluster import KMeans
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.neighbors import NearestCentroid

# Defina uma lista de algoritmos
algorithms = [
    ("Logistic Regression", LogisticRegression(max_iter=1000)),
    ("K-Nearest Neighbors", KNeighborsClassifier(n_neighbors=5)),
    ("Support Vector Machine", SVC(kernel="linear")),
    ("Decision Tree", DecisionTreeClassifier()),
    ("Random Forest", RandomForestClassifier(n_estimators=100)),
    ("Gradient Boosting", GradientBoostingClassifier()),
    ("AdaBoost", AdaBoostClassifier()),
    ("Naive Bayes", GaussianNB()),
    ("Neural Network", MLPClassifier(max_iter=1000)),
    ("Quadratic Discriminant Analysis", QuadraticDiscriminantAnalysis())
]

# Crie dicionários para armazenar as métricas
accuracy_scores = {}
precision_scores = {}
recall_scores = {}
f1_scores = {}

# Itere sobre os algoritmos
for name, classifier in algorithms:
    # Treine o modelo
    classifier.fit(X_train, y_train)

    # Faça previsões no conjunto de teste
    y_pred = classifier.predict(X_test)

    # Calcule as métricas
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    # Armazene as métricas nos dicionários
    accuracy_scores[name] = accuracy
    precision_scores[name] = precision
    recall_scores[name] = recall
    f1_scores[name] = f1

# Apresente um resumo das métricas
print("Resumo das Métricas para os Algoritmos:")
for name, _ in algorithms:
    print(f"Algoritmo: {name}")
    print(f"Acurácia: {accuracy_scores[name]:.2f}")
    print(f"Precisão: {precision_scores[name]:.2f}")
    print(f"Recall: {recall_scores[name]:.2f}")
    print(f"F1-Score: {f1_scores[name]:.2f}")
    print()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Resumo das Métricas para os Algoritmos:
# Algoritmo: Logistic Regression
# Acurácia: 0.86
# Precisão: 0.86
# Recall: 0.85
# F1-Score: 0.86
#
# Algoritmo: K-Nearest Neighbors
# Acurácia: 0.84
# Precisão: 0.85
# Recall: 0.83
# F1-Score: 0.84
#
# Algoritmo: Support Vector Machine
# Acurácia: 0.86
# Precisão: 0.86
# Recall: 0.85
# F1-Score: 0.86
#
# Algoritmo: Decision Tree
# Acurácia: 0.85
# Precisão: 0.86
# Recall: 0.85
# F1-Score: 0.85
#
# Algoritmo: Random Forest
# Acurácia: 0.89
# Precisão: 0.89
# Recall: 0.88
# F1-Score: 0.89
#
# Algoritmo: Gradient Boosting
# Acurácia: 0.88
# Precisão: 0.90
# Recall: 0.87
# F1-Score: 0.88
#
# Algoritmo: AdaBoost
# Acurácia: 0.87
# Precisão: 0.87
# Recall: 0.86
# F1-Score: 0.87
#
# Algoritmo: Naive Bayes
# Acurácia: 0.82
# Precisão: 0.83
# Recall: 0.82
# F1-Score: 0.82
#
# ...

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Defina os melhores algoritmos com base nos resultados anteriores
melhores_algoritmos = {
    "Random Forest": RandomForestClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "AdaBoost": AdaBoostClassifier(),
    "Neural Network": MLPClassifier(max_iter=1000)
}

# Dicionário para armazenar os resultados da validação cruzada
resultados = {}

# Realize a validação cruzada para cada um dos melhores algoritmos
for nome, algoritmo in melhores_algoritmos.items():
    # Realize a validação cruzada com 5 folds
    scores = cross_val_score(algoritmo, X_train, y_train, cv=5, scoring='accuracy')

    # Calcule as métricas médias
    acuracia_media = scores.mean()

    # Calcule o desvio padrão das métricas
    desvio_padrao_acuracia = scores.std()

    # Treine o modelo no conjunto de treinamento completo
    algoritmo.fit(X_train, y_train)

    # Faça previsões no conjunto de teste
    previsoes = algoritmo.predict(X_test)

    # Calcule outras métricas
    precisao = precision_score(y_test, previsoes)
    recall = recall_score(y_test, previsoes)
    f1 = f1_score(y_test, previsoes)

    # Armazene os resultados no dicionário
    resultados[nome] = {
        "Acurácia Média": acuracia_media,
        "Desvio Padrão da Acurácia": desvio_padrao_acuracia,
        "Precisão": precisao,
        "Recall": recall,
        "F1-Score": f1
    }

# Imprima um resumo dos resultados
print("Resumo das Métricas para os Melhores Algoritmos:")
for nome, metricas in resultados.items():
    print(f"Algoritmo: {nome}")
    print(f"Acurácia Média: {metricas['Acurácia Média']:.2f}")
    print(f"Desvio Padrão da Acurácia: {metricas['Desvio Padrão da Acurácia']:.5f}")
    print(f"Precisão: {metricas['Precisão']:.2f}")
    print(f"Recall: {metricas['Recall']:.2f}")
    print(f"F1-Score: {metricas['F1-Score']:.2f}")
    print()
# Out:
# Resumo das Métricas para os Melhores Algoritmos:
# Algoritmo: Random Forest
# Acurácia Média: 0.89
# Desvio Padrão da Acurácia: 0.00
# Precisão: 0.89
# Recall: 0.88
# F1-Score: 0.89
#
# Algoritmo: Gradient Boosting
# Acurácia Média: 0.88
# Desvio Padrão da Acurácia: 0.00
# Precisão: 0.90
# Recall: 0.87
# F1-Score: 0.88
#
# Algoritmo: AdaBoost
# Acurácia Média: 0.87
# Desvio Padrão da Acurácia: 0.00
# Precisão: 0.87
# Recall: 0.86
# F1-Score: 0.87
#
# Algoritmo: Neural Network
# Acurácia Média: 0.86
# Desvio Padrão da Acurácia: 0.00
# Precisão: 0.87
# Recall: 0.87
# F1-Score: 0.87

# %% [markdown]
# ## Tuning dos parâmetros

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# Defina os valores que você deseja testar para cada hiperparâmetro
param_grid = {
    'n_estimators': [50, 100],
    'max_depth': [5, 10],
    'criterion': ['gini', 'entropy']
}

# Crie o modelo RandomForestClassifier
rf = RandomForestClassifier()

# Crie a grade de pesquisa
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid,
                           scoring='accuracy', cv=5, n_jobs=-1)

# Treine o modelo para encontrar os melhores hiperparâmetros
grid_search.fit(X_train, y_train)

# Imprima os melhores hiperparâmetros
print("Melhores hiperparâmetros encontrados:")
print(grid_search.best_params_)

# Obtenha o modelo com os melhores hiperparâmetros
best_rf_model = grid_search.best_estimator_

# Avalie o modelo com os dados de teste
accuracy = best_rf_model.score(X_test, y_test)
print(f"Acurácia do modelo com os melhores hiperparâmetros: {accuracy}")
# Out:
# Melhores hiperparâmetros encontrados:
# {'criterion': 'entropy', 'max_depth': 10, 'n_estimators': 50}
# Acurácia do modelo com os melhores hiperparâmetros: 0.8666396979503775

# %% [markdown]
# ## Seleção de atributos

# %%
data_encoded
# Out:
#             age  final-weight  education-num  capital-gain  capital-loos  \
# 0     -0.106436     -1.067722       1.034900      0.013732     -0.257101
# 1      0.779494     -1.012399       1.034900     -0.196484     -0.257101
# 2     -0.186975      0.250965      -0.603902     -0.196484     -0.257101
# 3      1.021111      0.433069      -1.423304     -0.196484     -0.257101
# 4     -0.992365      1.422948       1.034900     -0.196484     -0.257101
# ...         ...           ...            ...           ...           ...
# 49435  0.135181     -0.480742      -0.194202     -0.196484     -0.257101
# 49436  0.376799      1.379893       1.034900     -0.196484     -0.257101
# 49437 -0.025897     -1.261358      -0.194202     -0.196484     -0.257101
# 49438  1.423806     -0.372015       1.034900     -0.196484     -0.257101
# 49439  0.054642     -0.053393      -0.194202     -0.196484     -0.257101
#
#        hour-per-week  workclass_0  workclass_1  workclass_2  workclass_3  ...  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# Criar um novo modelo Random Forest com os melhores hiperparâmetros
best_rf_model = RandomForestClassifier(criterion='entropy', max_depth=10, n_estimators=50)

# Treinar o modelo com os dados de treinamento resampledados
best_rf_model.fit(data_encoded, y_resampled)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=10, n_estimators=50)

# %%
from sklearn.feature_selection import SelectFromModel
import matplotlib.pyplot as plt

# Criar um seletor de atributos usando o modelo Random Forest ajustado
selector = SelectFromModel(best_rf_model)

# Treinar o seletor com os dados de treinamento
selector.fit(data_encoded, y_resampled)

# Obter os índices dos atributos selecionados
selected_features = selector.get_support(indices=True)

# Nome dos atributos selecionados
selected_feature_names = data_encoded.columns[selected_features]

# Gráfico de importância dos atributos
feature_importances = best_rf_model.feature_importances_
plt.figure(figsize=(12, 6))
plt.bar(selected_feature_names, feature_importances[selected_features])
plt.xlabel('Atributos')
plt.ylabel('Importância')
plt.title('Importância dos Atributos (Top 5)')
plt.xticks(rotation=45)
plt.show()

# %%
# Selecionar apenas os atributos mais importantes
X_selected = data_encoded[selected_feature_names]

# Dividir os dados em treinamento e teste
X_train_selected, X_test_selected, y_train_selected, y_test_selected = train_test_split(
    X_selected, y_resampled, test_size=0.3, random_state=42)

# Criar um novo modelo Random Forest com os melhores hiperparâmetros
best_rf_model_selected = RandomForestClassifier(criterion='entropy', max_depth=10, n_estimators=50)

# Treinar o modelo com os atributos mais importantes
best_rf_model_selected.fit(X_train_selected, y_train_selected)

# Avaliar o desempenho do modelo com os atributos mais importantes
accuracy_selected = best_rf_model_selected.score(X_test_selected, y_test_selected)

# Exibir a acurácia do modelo com os atributos mais importantes
print(f'Acurácia com os atributos mais importantes: {accuracy_selected:.2f}')
# Out:
# Acurácia com os atributos mais importantes: 0.87

# %% [markdown]
# ## Modelo final

# %%
data_encoded.shape
# Out:
# (49440, 105)

# %%
from sklearn.ensemble import RandomForestClassifier
import joblib

# Criar um novo modelo Random Forest com os melhores hiperparâmetros
best_rf_model = RandomForestClassifier(criterion='entropy', max_depth=10, n_estimators=50)

# Treinar o modelo com os dados de treinamento resampledados
best_rf_model.fit(data_encoded, y_resampled)

# Salvar o modelo treinado no disco
joblib.dump(best_rf_model, 'random_forest_model.pkl')
# Out:
# ['random_forest_model.pkl']

# %%
import joblib

# Carregar o modelo treinado do disco
loaded_rf_model = joblib.load('random_forest_model.pkl')


# Seu dado em formato de lista
new_data = data_encoded.iloc[[0]]

# Agora você pode fazer a previsão
predictions = loaded_rf_model.predict(new_data)
print(predictions)
# Out:
# [0]

# %%
new_data
# Out:
#         age  final-weight  education-num  capital-gain  capital-loos  \
# 0 -0.106436     -1.067722         1.0349      0.013732     -0.257101
#
#    hour-per-week  workclass_0  workclass_1  workclass_2  workclass_3  ...  \
# 0      -0.177616    -0.181754    -0.281078     -0.17707    -1.566898  ...
#
#    native-country_31  native-country_32  native-country_33  native-country_34  \
# 0          -0.053859          -0.068515          -0.045244          -0.066089
#
#    native-country_35  native-country_36  native-country_37  native-country_38  \
# 0          -0.067008          -0.061783          -0.063089           0.332434
#
#    native-country_39  native-country_40
# 0          -0.038978          -0.017992
#
# [1 rows x 105 columns]
